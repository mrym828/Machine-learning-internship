# %% [markdown]
# <a href="https://colab.research.google.com/github/mrym828/Machine-learning-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# i chose Structured Content Archetype clustering because the engagement rate numbers shows that most pages are near zero while smaller group are more. so this content isn't one group, instead it's a different types of pages mixed together. This is interesting to me because clustering simply group pages by their behavior patterns and it produces named Archetypes. that a reviewer could use to make decisions regarding the pages, instead of reviewing 30000 pages one by one.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# My work would improve an SEO specialist's decision about which pages to prioritize for update or rewrite, which to leave alone and monitor, and which aren't worth keeping. A wrong call here has two different costs: if a page that actually needs work gets labeled as fine, the site loses out on traffic it could have recovered; if a page that's actually fine gets flagged as needing work, the specialist wastes limited time on a page that didn't need it.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mrym828/Machine-learning-internship/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df['content_type'].value_counts()
# Out:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64

# %%
df['engagement_rate'].describe()
# Out:
# count    30000.000000
# mean         2.534520
# std          8.310096
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.350000
# max        100.000000
# Name: engagement_rate, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My work observed that pages split into groups with very different engagement levels which is that most pages get near-zero engagement, while a smaller group performs better. Grouping pages this way would make it easier for an SEO specialist to identify which pages to modify, monitor, or leave alone. My work will not claim that a page's content (like short length) is the reason Google ranks it poorly, and it will not claim that modifying a page will cause it to move into a better-performing cluster, only a real experiment could prove that. My claims are limited to what was observed: which pages group together and how their real, measured metrics compare.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
